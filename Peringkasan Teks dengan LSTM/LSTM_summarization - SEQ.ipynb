# %%
# %% Import required libraries
import json
import pandas as pd
import numpy as np
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, SimpleRNN, Embedding, Dense, TimeDistributed
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, LearningRateScheduler
import matplotlib.pyplot as plt
from rouge import Rouge  # For evaluation metrics
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import SimpleRNN, Dense, Embedding
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.utils import to_categorical

# %%
# %% Define function to load JSONL dataset from multiple files
def load_dataset(paths):
    data = []
    for path in paths:
        with open(path, 'r', encoding='utf-8') as f:
            for line in f:
                data.append(json.loads(line))
    return data

# Specify the list of JSONL file paths for training
file_paths = [
    'indosum/train.01.jsonl',
    'indosum/train.02.jsonl',
    'indosum/train.03.jsonl',
    'indosum/train.04.jsonl',
    'indosum/train.05.jsonl'
]

# Load all JSONL files into a dataset
dataset_jsonl = load_dataset(file_paths)

# %%
len(dataset_jsonl)
# Out:
# 71353

# %%
dataset_jsonl[0]
# Out:
# {'category': 'tajuk utama',
#  'gold_labels': [[False, True],
#   [True, True],
#   [False, False, False],
#   [False, False],
#   [False, False],
#   [False, False],
#   [False, False],
#   [False],
#   [False, False]],
#  'id': '1501893029-lula-kamal-dokter-ryan-thamrin-sakit-sejak-setahun',
#  'paragraphs': [[['Jakarta',
#     ',',
#     'CNN',
#     'Indonesia',
#     '-',
#     '-',
#     'Dokter',
#     'Ryan',
#     'Thamrin',
#     ',',
#     'yang',
#     'terkenal',
#     'lewat',
#     'acara',
#     'Dokter',
#     'Oz',
#     'Indonesia',
#     ',',
#     'meninggal',
#     'dunia',
#     'pada',
#     'Jumat',
#     '(',
#     '4',
#     '/',
#     '8',
#     ')',
#     'dini',
#     'hari',
#     '.'],
#    ['Dokter',
#     'Lula',
#     'Kamal',
#     'yang',
#     'merupakan',
#     'selebriti',
#     'sekaligus',
#     'rekan',
#     'kerja',
#     'Ryan',
#     'menyebut',
#     'kawannya',
#     'itu',
#     'sudah',
#     'sakit',
#     'sejak',
#     'setahun',
#     'yang',
#     'lalu',
#     '.']],
#   [['Lula',
#     'menuturkan',
#     ',',
#     'sakit',
#     'itu',
#     'membuat',
#     'Ryan',
#     'mesti',
#     'vakum',
#     'dari',
#     'semua',
#     'kegiatannya',
#     ',',
#     'termasuk',
#     'menjadi',
#     'pembawa',
#     'acara',
#     'Dokter',
#     'Oz',
#     'Indonesia',
#     '.'],
#    ['Kondisi',
#     'itu',
#     'membuat',
#     'Ryan',
#     'harus',
#     'kembali',
#     'ke',
#     'kampung',
#     'halamannya',
#     'di',
#     'Pekanbaru',
#     ',',
#     'Riau',
#     'untuk',
#     'menjalani',
#     'istirahat',
#     '.']],
#   [['"',
#     'Setahu',
#     'saya',
#     'dia',
#     'orangnya',
#     'sehat',
#     ',',
#     'tapi',
#     'tahun',
#     'lalu',
#     'saya',
#     'dengar',
#     'dia',
#     'sakit',
#     '.'],
#    ['(',
#     'Karena',
#     ')',
#     'sakitnya',
#     ',',
#     'ia',
#     'langsung',
#     'pulang',
#     'ke',
#     'Pekanbaru',
#     ',',
#     'jadi',
#     'kami',
#     'yang',
#     'mau',
#     'jenguk',
#     'juga',
#     'susah',
#     '.'],
#    ['Barangkali',
#     'mau',
#     'istirahat',
#     ',',
#     'ya',
#     'betul',
#     'juga',
#     ',',
#     'kalau',
#     'di',
#     'Jakarta',
#     'susah',
#     'isirahatnya',
#     ',',
#     '"',
#     'kata',
#     'Lula',
#     'kepada',
#     'CNNIndonesia.com',
#     ',',
#     'Jumat',
#     '(',
#     '4',
#     '/',
#     '8',
#     ')',
#     '.']],
#   [['Lula',
#     'yang',
#     'mengenal',
#     'Ryan',
#     'sejak',
#     'sebelum',
#     'aktif',
#     'berkarier',
#     'di',
#     'televisi',
#     'mengaku',
#     'belum',
#     'sempat',
#     'membesuk',
#     'Ryan',
#     'lantaran',
#     'lokasi',
#     'yang',
#     'jauh',
#     '.'],
#    ['Dia',
#     'juga',
#     'tak',
#     'tahu',
#     'penyakit',
#     'apa',
#     'yang',
#     'diderita',
#     'Ryan',
#     '.']],
#   [['"',
#     'Itu',
#     'saya',
#     'enggak',
#     'tahu',
#     ',',
#     'belum',
#     'sempat',
#     'jenguk',
#     'dan',
#     'enggak',
#     'selamanya',
#     'bisa',
#     'dijenguk',
#     'juga',
#     '.'],
#    ['Enggak',
#     'tahu',
#     'berat',
#     'sekali',
#     'apa',
#     'bagaimana',
#     ',',
#     '"',
#     'tutur',
#     'Ryan',
#     '.']],
#   [['Walau',
#     'sudah',
#     'setahun',
#     'menderita',
#     'sakit',
#     ',',
#     'Lula',
#     'tak',
#     'mengetahui',
#     'apa',
#     'penyebab',
#     'pasti',
#     'kematian',
#     'Dr',
#     'Oz',
#     'Indonesia',
#     'itu',
#     '.'],
#    ['Meski',
#     'demikian',
#     ',',
#     'ia',
#     'mendengar',
#     'beberapa',
#     'kabar',
#     'yang',
#     'menyebut',
#     'bahwa',
#     'penyebab',
#     'Ryan',
#     'meninggal',
#     'adalah',
#     'karena',
#     'jatuh',
#     'di',
#     'kamar',
#     'mandi',
#     '.']],
#   [['“',
#     'Saya',
#     'tidak',
#     'tahu',
#     ',',
#     'barangkali',
#     'penyakit',
#     'yang',
#     'dulu',
#     'sama',
#     'yang',
#     'sekarang',
#     'berbeda',
#     ',',
#     'atau',
#     'penyebab',
#     'kematiannya',
#     'beda',
#     'dari',
#     'penyakit',
#     'sebelumnya',
#     '.'],
#    ['Kita',
#     'kan',
#     'enggak',
#     'bisa',
#     'mengambil',
#     'kesimpulan',
#     ',',
#     '"',
#     'kata',
#     'Lula',
#     '.']],
#   [['Ryan',
#     'Thamrin',
#     'terkenal',
#     'sebagai',
#     'dokter',
#     'yang',
#     'rutin',
#     'membagikan',
#     'tips',
#     'dan',
#     'informasi',
#     'kesehatan',
#     'lewat',
#     'tayangan',
#     'Dokter',
#     'Oz',
#     'Indonesia',
#     '.']],
#   [['Ryan',
#     'menempuh',
#     'Pendidikan',
#     'Dokter',
#     'pada',
#     'tahun',
#     '2002',
#     'di',
#     'Fakultas',
#     'Kedokteran',
#     'Universitas',
#     'Gadjah',
#     'Mada',
#     '.'],
#    ['Dia',
#     'kemudian',
#     'melanjutkan',
#     'pendidikan',
#     'Klinis',
#     'Kesehatan',
#     'Reproduksi',
#     'dan',
#     'Penyakit',
#     'Menular',
#     'Seksual',
#     'di',
#     'Mahachulalongkornrajavidyalaya',
#     'University',
#     ',',
#     'Bangkok',
#     ',',
#     'Thailand',
#     'pada',
#     '2004',
#     '.']]],
#  'source': 'cnn indonesia',
#  'source_url': 'https://www.cnnindonesia.com/hiburan/20170804120703-234-232443/lula-kamal-dokter-ryan-thamrin-sakit-sejak-setahun-lalu/',
#  'summary': [['Dokter',
#    'Lula',
#    'Kamal',
#    'yang',
#    'merupakan',
#    'selebriti',
#    'sekaligus',
#    'rekan',
#    'kerja',
#    'Ryan',
#    'Thamrin',
#    'menyebut',
#    'kawannya',
#    'itu',
#    'sudah',
#    'sakit',
#    'sejak',
#    'setahun',
#    'yang',
#    'lalu',
#    '.'],
#   ['Lula',
#    'menuturkan',
#    ',',
#    'sakit',
#    'itu',
#    'membuat',
#    'Ryan',
#    'mesti',
#    'vakum',
#    'dari',
#    'semua',
#    'kegiatannya',
#    ',',
#    'termasuk',
#    'menjadi',
#    'pembawa',
#    'acara',
#    'Dokter',
#    'Oz',
#    'Indonesia',
#    '.'],
#   ['Kondisi',
#    'itu',
#    'membuat',
#    'Ryan',
#    'harus',
#    'kembali',
#    'ke',
#    'kampung',
#    'halamannya',
#    'di',
#    'Pekanbaru',
#    ',',
#    'Riau',
#    'untuk',
#    'menjalani',
#    'istirahat',
#    '.']]}

# %%
dataset_jsonl[0].keys()
# Out:
# dict_keys(['category', 'gold_labels', 'id', 'paragraphs', 'source', 'source_url', 'summary'])

# %%
# %% Extract and clean data
# Initialize lists for data extraction
ids, categories, sources, urls, texts, summaries = [], [], [], [], [], []

# Process each entry in the dataset
for entry in dataset_jsonl:
    ids.append(entry['id'])
    categories.append(entry['category'])
    sources.append(entry['source'])
    urls.append(entry['source_url'])
    
    # Combine all tokens in paragraphs into one string for the text
    full_text = ''.join([' '.join([' '.join(sentence) for sentence in paragraph]) for paragraph in entry['paragraphs']])
    texts.append(full_text)
    
    # Combine tokens in summary into one string if available
    if 'summary' in entry:
        full_summary = ' '.join([' '.join(sentence) for sentence in entry['summary']])
        summaries.append(full_summary)

# Create DataFrame from extracted data
df = pd.DataFrame({
    "id": ids,
    "text": texts,
    "summary": summaries,
    "category": categories,
    "source": sources,
    "url": urls
})

# %%
df.head()
# Out:
#                                                   id  \
# 0  1501893029-lula-kamal-dokter-ryan-thamrin-saki...
# 1  1509072914-dua-smartphone-zenfone-baru-tawarka...
# 2  1510613677-songsong-visit-2020-bengkulu-perkua...
# 3  1502706803-icw-ada-kejanggalan-atas-tewasnya-s...
# 4  1503039338-pembagian-sepeda-usai-upacara-penur...
#
#                                                 text  \
# 0  Jakarta , CNN Indonesia - - Dokter Ryan Thamri...
# 1  Selfie ialah salah satu tema terpanas di kalan...
# 2  Jakarta , CNN Indonesia - - Dinas Pariwisata P...
# 3  Merdeka.com - Indonesia Corruption Watch ( ICW...
# 4  Merdeka.com - Presiden Joko Widodo ( Jokowi ) ...
#
#                                              summary     category  \
# 0  Dokter Lula Kamal yang merupakan selebriti sek...  tajuk utama
# 1  Asus memperkenalkan   ZenFone generasi keempat...    teknologi
# 2  Dinas Pariwisata Provinsi Bengkulu kembali men...      hiburan
# 3  Indonesia Corruption Watch ( ICW ) meminta Kom...  tajuk utama
# 4  Jokowi memimpin upacara penurunan bendera . Us...  tajuk utama
#
#            source                                                url
# 0   cnn indonesia  https://www.cnnindonesia.com/hiburan/201708041...
# 1  dailysocial.id  https://dailysocial.id/post/dua-smartphone-zen...
# 2   cnn indonesia  https://www.cnnindonesia.com/gaya-hidup/201711...
# 3         merdeka  https://www.merdeka.com/peristiwa/icw-merasa-a...
# 4         merdeka  https://www.merdeka.com/peristiwa/usai-upacara...

# %%
len(df)
# Out:
# 71353

# %%
df = df.drop_duplicates(subset=['id'])
len(df)
# Out:
# 18773

# %%
df['source'].unique()
# Out:
# array(['cnn indonesia', 'dailysocial.id', 'merdeka', 'goal indonesia',
#        'juara.net', 'kumparan', 'poskotanews', 'suara', 'antaranews',
#        'rimanews'], dtype=object)

# %%
# Display the first row for each unique source
df.groupby('source').head(1)
# Out:
#                                                    id  \
# 0   1501893029-lula-kamal-dokter-ryan-thamrin-saki...
# 1   1509072914-dua-smartphone-zenfone-baru-tawarka...
# 3   1502706803-icw-ada-kejanggalan-atas-tewasnya-s...
# 5              1512519514-hasil-indonesia-vs-mongolia
# 8   1491930003-persib-pastikan-jamu-arema-di-stadi...
# 9   1501262100-seberapa-butuh-juventus-akan-keita-...
# 17  1512116100-semua-jalur-pendakian-ke-gunung-ged...
# 28  1516575600-setahun-berkuasa-trump-didemo-antid...
# 31  1504684800-hotel-ini-sewakan-ikan-untuk-tamu-k...
# 34  1482552044-wanita-muslim-akan-jadi-perdana-men...
#
#                                                  text  \
# 0   Jakarta , CNN Indonesia - - Dokter Ryan Thamri...
# 1   Selfie ialah salah satu tema terpanas di kalan...
# 3   Merdeka.com - Indonesia Corruption Watch ( ICW...
# 5   Timnas Indonesia hanya mampu meraih kemenangan...
# 8   BANDUNG , JUARA.net - Persib Bandung dipastika...
# 9   Sejauh bursa transfer musim panas 2017 / 18 di...
# 17  SUKABUMI ( Pos Kota ) – Jalur pendakian ke Tam...
# 28  Suara.com - Ribuan perempuan di Washington CD ...
# 31  Jakarta ( ANTARA News ) - Sebuah hotel di Belg...
# 34  Rimanews -   Rumania akan dipimpin oleh seoran...
#
#                                               summary     category  \
# 0   Dokter Lula Kamal yang merupakan selebriti sek...  tajuk utama
# 1   Asus memperkenalkan   ZenFone generasi keempat...    teknologi
# 3   Indonesia Corruption Watch ( ICW ) meminta Kom...  tajuk utama
# 5   Timnas Indonesia hanya mampu meraih kemenangan...     olahraga
# 8   Persib Bandung dipastikan bakal menggunakan St...     olahraga
# 9   Sejauh bursa transfer musim panas 2017 / 18 di...     olahraga
# 17  Jalur pendakian ke Taman Naslonal Gunung Gede ...  tajuk utama
# 28    Ribuan perempuan di Washington CD , Amerika ...  tajuk utama
# 31  Sebuah hotel di Belgia menawarkan sewa ikan un...      hiburan
# 34  Rumania akan dipimpin oleh seorang perdana men...  tajuk utama
#
#             source                                                url
# 0    cnn indonesia  https://www.cnnindonesia.com/hiburan/201708041...
# 1   dailysocial.id  https://dailysocial.id/post/dua-smartphone-zen...
# 3          merdeka  https://www.merdeka.com/peristiwa/icw-merasa-a...
# 5   goal indonesia  http://www.goal.com/id/berita/laporan-pertandi...
# 8        juara.net  http://www.juara.net/read/sepak-bola/indonesia...
# 9         kumparan  https://kumparan.com/rossi-finza-noor/seberapa...
# 17     poskotanews  http://poskotanews.com/2017/11/30/semua-jalur-...
# 28           suara  https://www.suara.com/news/2018/01/21/080611/s...
# 31      antaranews  http://www.antaranews.com/berita/650778/hotel-...
# 34        rimanews  http://rimanews.com/internasional/eropa/read/2...

# %%
# %% Preprocess the text and summary (cleaning)
import re

# Define text cleaner function
sources = np.array([
    'cnn indonesia', 'dailysocial id', 'merdeka com', 'goal indonesia',
    'juara net', 'kumparan', 'poskotanews', 'pos kota', 'suara com', 'antaranews', 'antara news'
    'rimanews'
])

def text_cleaner(text):
    text = text.lower()  # Convert to lowercase
    text = re.sub(r"[^a-zA-Z0-9\s]", " ", text)  # Remove special characters
    text = re.sub(r'\b(?:' + '|'.join(re.escape(word) for word in sources) + r')\b', "", text)
    text = re.sub(r'\s+', ' ', text).strip()  # Remove extra whitespaces
    return text

# %%
# Text cleaner function test usage
before = df['text'][0]
after = text_cleaner(before)

print(before)
print(after)
# Out:
# Jakarta , CNN Indonesia - - Dokter Ryan Thamrin , yang terkenal lewat acara Dokter Oz Indonesia , meninggal dunia pada Jumat ( 4 / 8 ) dini hari . Dokter Lula Kamal yang merupakan selebriti sekaligus rekan kerja Ryan menyebut kawannya itu sudah sakit sejak setahun yang lalu .Lula menuturkan , sakit itu membuat Ryan mesti vakum dari semua kegiatannya , termasuk menjadi pembawa acara Dokter Oz Indonesia . Kondisi itu membuat Ryan harus kembali ke kampung halamannya di Pekanbaru , Riau untuk menjalani istirahat ." Setahu saya dia orangnya sehat , tapi tahun lalu saya dengar dia sakit . ( Karena ) sakitnya , ia langsung pulang ke Pekanbaru , jadi kami yang mau jenguk juga susah . Barangkali mau istirahat , ya betul juga , kalau di Jakarta susah isirahatnya , " kata Lula kepada CNNIndonesia.com , Jumat ( 4 / 8 ) .Lula yang mengenal Ryan sejak sebelum aktif berkarier di televisi mengaku belum sempat membesuk Ryan lantaran lokasi yang jauh . Dia juga tak tahu penyakit apa yang diderita Ryan ." Itu saya enggak tahu , belum sempat jenguk dan enggak selamanya bisa dijenguk juga . Enggak tahu berat sekali apa bagaimana , " tutur Ryan .Walau sudah setahun menderita sakit , Lula tak mengetahui apa penyebab pasti kematian Dr Oz Indonesia itu . Meski demikian , ia mendengar beberapa kabar yang menyebut bahwa penyebab Ryan meninggal adalah karena jatuh di kamar mandi .“ Saya tidak tahu , barangkali penyakit yang dulu sama yang sekarang berbeda , atau penyebab kematiannya beda dari penyakit sebelumnya . Kita kan enggak bisa mengambil kesimpulan , " kata Lula .Ryan Thamrin terkenal sebagai dokter yang rutin membagikan tips dan informasi kesehatan lewat tayangan Dokter Oz Indonesia .Ryan menempuh Pendidikan Dokter pada tahun 2002 di Fakultas Kedokteran Universitas Gadjah Mada . Dia kemudian melanjutkan pendidikan Klinis Kesehatan Reproduksi dan Penyakit Menular Seksual di Mahachulalongkornrajavidyalaya University , Bangkok , Thailand pada 2004 .
# jakarta dokter ryan thamrin yang terkenal lewat acara dokter oz indonesia meninggal dunia pada jumat 4 8 dini hari dokter lula kamal yang merupakan selebriti sekaligus rekan kerja ryan menyebut kawannya itu sudah sakit sejak setahun yang lalu lula menuturkan sakit itu membuat ryan mesti vakum dari semua kegiatannya termasuk menjadi pembawa acara dokter oz indonesia kondisi itu membuat ryan harus kembali ke kampung halamannya di pekanbaru riau untuk menjalani istirahat setahu saya dia orangnya sehat tapi tahun lalu saya dengar dia sakit karena sakitnya ia langsung pulang ke pekanbaru jadi kami yang mau jenguk juga susah barangkali mau istirahat ya betul juga kalau di jakarta susah isirahatnya kata lula kepada cnnindonesia com jumat 4 8 lula yang mengenal ryan sejak sebelum aktif berkarier di televisi mengaku belum sempat membesuk ryan lantaran lokasi yang jauh dia juga tak tahu penyakit apa yang diderita ryan itu saya enggak tahu belum sempat jenguk dan enggak selamanya bisa dijenguk juga enggak tahu berat sekali apa bagaimana tutur ryan walau sudah setahun menderita sakit lula tak mengetahui apa penyebab pasti kematian dr oz indonesia itu meski demikian ia mendengar beberapa kabar yang menyebut bahwa penyebab ryan meninggal adalah karena jatuh di kamar mandi saya tidak tahu barangkali penyakit yang dulu sama yang sekarang berbeda atau penyebab kematiannya beda dari penyakit sebelumnya kita kan enggak bisa mengambil kesimpulan kata lula ryan thamrin terkenal sebagai dokter yang rutin membagikan tips dan informasi kesehatan lewat tayangan dokter oz indonesia ryan menempuh pendidikan dokter pada tahun 2002 di fakultas kedokteran universitas gadjah mada dia kemudian melanjutkan pendidikan klinis kesehatan reproduksi dan penyakit menular seksual di mahachulalongkornrajavidyalaya university bangkok thailand pada 2004

# %%
# Apply text cleaner function
df['text'] = df['text'].apply(text_cleaner)
df['summary'] = df['summary'].apply(text_cleaner)

# %%
# Example result after cleaning
print(df['text'][10])
print(df['summary'][10])
# Out:
# jakarta militer amerika serikat akan melakukan uji coba rudal balistik antarbenua icbm pada rabu 2 8 waktu setempat berselang beberapa hari setelah korut meluncurkan icbm pekan lalu seorang pejabat militer as mengatakan uji coba rudal minuteman iii itu akan dilaksanakan di pangkalan udara vanderberg antara pukul 00 01 dan 06 01 waktu california tujuan dari program uji coba peluncuran icbm ini adalah untuk memvalidasi dan memverifikasi keefektifan kesiapan dan keakuratan sistem senjata ini demikian pernyataan komando serangan global angkatan udara as sebagaimana dilansir afp uji coba semacam ini biasanya direncanakan dari jauh hari namun uji coba ini direncanakan dalam waktu singkat tepat setelah korut menguji coba icbm pada jumat lalu sejak awal tahun pemimpin tertinggi korut kim jong un memang selalu memamerkan perkembangan program icbm negaranya pada juli saja korut sudah melakukan dua kali uji coba icbm yang dianggap sukses pada uji coba pertama kim menyebut uji coba itu merupakan hadiah bagi para bajingan amerika rudal itu memang diklaim dapat mencapai alaska rudal yang dipakai pada uji coba kedua dianggap lebih mutakhir dan dapat mencapai wilayah new york tapi para pejabat as masih meragukan kemampuan icbm korut setelah korut melakukan uji coba pada pekan lalu pejabat intelijen as akhirnya mengakui bahwa icbm yang dikembangkan korut memang dapat mencapai wilayah negaranya
# militer as dikabarkan akan melakukan uji coba rudal balistik antar benua icbm pada rabu 2 8 waktu setempat pekan sebelumnya korut juga melakukan aktivitas serupa dan sukses rudal korut diklaim dapat mencapai wilayah new york klaim tersebut kemudian diakui pula oleh pejabat intelijen as bagaimana jadinya jika kedua negara ini berduet rudal

# %%
# %% Analyze length distribution of text and summary
text_word_count = [len(text.split()) for text in df['text']]
summary_word_count = [len(summary.split()) for summary in df['summary']]

# Plot histograms
length_df = pd.DataFrame({'text': text_word_count, 'summary': summary_word_count})
length_df.hist(bins=30)
plt.show()

# %%
# Set maximum lengths based on histogram
max_text_len = 250
max_summary_len = 60

# %%
# Filter short texts and summaries based on maximum length
cleaned_text =np.array(df['text'])
cleaned_summary=np.array(df['summary'])

short_text=[]
short_summary=[]

for i in range(len(cleaned_text)):
    if(len(cleaned_summary[i].split())<=max_summary_len and len(cleaned_text[i].split())<=max_text_len):
        short_text.append(cleaned_text[i])
        short_summary.append(cleaned_summary[i])

# %%
df_short=pd.DataFrame({'text':short_text,'summary':short_summary})
df_short.head()
# Out:
#                                                 text  \
# 0  jakarta militer amerika serikat akan melakukan...
# 1  jakarta runner up motogp 2017 andrea dovizioso...
# 2  brimob polda metro jaya mendatangi kantor lkbn...
# 3  ribuan perempuan di washington cd amerika seri...
# 4  rimanews rumania akan dipimpin oleh seorang pe...
#
#                                              summary
# 0  militer as dikabarkan akan melakukan uji coba ...
# 1  runner up motogp 2017 andrea dovizioso mengaku...
# 2  brimob polda metro jaya mendatangi kantor lkbn...
# 3  ribuan perempuan di washington cd amerika seri...
# 4  rumania akan dipimpin oleh seorang perdana men...

# %%
print(df_short['text'].str.split().str.len().max())
print(df_short['summary'].str.split().str.len().max())
# Out:
# 250
# 60

# %%
# Add start and end tokens to summaries
df_filtered_full = pd.DataFrame({'text': df_short['text'], 'summary': df_short['summary']})
# df_filtered_full['summary'] = df_filtered_full['summary'].apply(lambda x: 'sostok ' + x + ' eostok')

# %%
df_filtered_full.head()
# Out:
#                                                 text  \
# 0  jakarta militer amerika serikat akan melakukan...
# 1  jakarta runner up motogp 2017 andrea dovizioso...
# 2  brimob polda metro jaya mendatangi kantor lkbn...
# 3  ribuan perempuan di washington cd amerika seri...
# 4  rimanews rumania akan dipimpin oleh seorang pe...
#
#                                              summary
# 0  militer as dikabarkan akan melakukan uji coba ...
# 1  runner up motogp 2017 andrea dovizioso mengaku...
# 2  brimob polda metro jaya mendatangi kantor lkbn...
# 3  ribuan perempuan di washington cd amerika seri...
# 4  rumania akan dipimpin oleh seorang perdana men...

# %%
df_filtered = df_filtered_full[:1000]

# %%
# %% Split dataset into training and validation sets
from sklearn.model_selection import train_test_split
train_df, val_df = train_test_split(df_filtered, test_size=0.2, random_state=42)

# %%
# %% Tokenize and pad sequences
tokenizer = Tokenizer()
tokenizer.fit_on_texts(train_df['text'].tolist() + train_df['summary'].tolist())

# Convert text and summary into sequences
train_text_seq = pad_sequences(tokenizer.texts_to_sequences(train_df['text']), maxlen=max_text_len, padding='post')
train_summary_seq = pad_sequences(tokenizer.texts_to_sequences(train_df['summary']), maxlen=max_summary_len, padding='post')
val_text_seq = pad_sequences(tokenizer.texts_to_sequences(val_df['text']), maxlen=max_text_len, padding='post')
val_summary_seq = pad_sequences(tokenizer.texts_to_sequences(val_df['summary']), maxlen=max_summary_len, padding='post')
target_data = train_summary_seq

# %%
# %% Define the RNN-based Encoder-Decoder model
# Define model parameters
vocab_size = len(tokenizer.word_index) + 1  # +1 for padding token
embedding_dim = 300  # Dimension of the embedding space
latent_dim = 300  # Latent dimensionality of the RNN

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Embedding
from tensorflow.keras.callbacks import EarlyStopping, LearningRateScheduler
from tensorflow.keras.optimizers import Adam

# Define the model with max_summary_len
model = Sequential([
    Embedding(input_dim=vocab_size, output_dim=embedding_dim, input_length=max_summary_len),
    LSTM(units=latent_dim, return_sequences=True),  # Replace SimpleRNN with LSTM
    Dense(vocab_size, activation='softmax')
])

# Compile the model
optimizer = Adam(learning_rate=0.001)
model.compile(optimizer=optimizer, loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Learning rate schedule function
def lr_schedule(epoch):
    initial_lr = 0.001
    lr_decay = 0.95
    return initial_lr * (lr_decay ** epoch)

# Early stopping
early_stopping = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)

# Train the model
batch_size = 32
epochs = 25
history = model.fit(
    train_summary_seq,   # Use target length sequences as input
    target_data, 
    batch_size=batch_size, 
    epochs=epochs, 
    validation_data=(val_summary_seq, val_summary_seq),  # Validation on summary length as well
    callbacks=[LearningRateScheduler(lr_schedule), early_stopping]
)
# Out:
# Epoch 1/25
# c:\Users\ILHAM\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 40s 1s/step - accuracy: 0.0746 - loss: 9.4562 - val_accuracy: 0.1224 - val_loss: 7.4322 - learning_rate: 0.0010
# Epoch 2/25
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 37s 1s/step - accuracy: 0.0520 - loss: 7.9269 - val_accuracy: 0.1224 - val_loss: 7.2762 - learning_rate: 9.5000e-04
# Epoch 3/25
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 37s 1s/step - accuracy: 0.0485 - loss: 7.6432 - val_accuracy: 0.1224 - val_loss: 6.8431 - learning_rate: 9.0250e-04
# Epoch 4/25
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 35s 1s/step - accuracy: 0.0522 - loss: 7.2513 - val_accuracy: 0.1230 - val_loss: 6.6217 - learning_rate: 8.5737e-04
# Epoch 5/25
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 36s 1s/step - accuracy: 0.0544 - loss: 7.0197 - val_accuracy: 0.1311 - val_loss: 6.4881 - learning_rate: 8.1451e-04
# Epoch 6/25
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 37s 1s/step - accuracy: 0.0641 - loss: 6.9139 - val_accuracy: 0.1371 - val_loss: 6.3980 - learning_rate: 7.7378e-04
# Epoch 7/25
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 34s 1s/step - accuracy: 0.0721 - loss: 6.8041 - val_accuracy: 0.1407 - val_loss: 6.3256 - learning_rate: 7.3509e-04
# Epoch 8/25
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 34s 1s/step - accuracy: 0.0805 - loss: 6.7370 - val_accuracy: 0.1543 - val_loss: 6.2637 - learning_rate: 6.9834e-04
# Epoch 9/25
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 36s 1s/step - accuracy: 0.0878 - loss: 6.6569 - val_accuracy: 0.1586 - val_loss: 6.2048 - learning_rate: 6.6342e-04
# Epoch 10/25
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 35s 1s/step - accuracy: 0.0944 - loss: 6.5747 - val_accuracy: 0.1684 - val_loss: 6.1491 - learning_rate: 6.3025e-04
# Epoch 11/25
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 36s 1s/step - accuracy: 0.1003 - loss: 6.5097 - val_accuracy: 0.1697 - val_loss: 6.0905 - learning_rate: 5.9874e-04
# Epoch 12/25
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 34s 1s/step - accuracy: 0.1036 - loss: 6.4601 - val_accuracy: 0.1795 - val_loss: 6.0376 - learning_rate: 5.6880e-04
# Epoch 13/25
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 34s 1s/step - accuracy: 0.1144 - loss: 6.3556 - val_accuracy: 0.1833 - val_loss: 5.9770 - learning_rate: 5.4036e-04
# Epoch 14/25
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 33s 1s/step - accuracy: 0.1225 - loss: 6.2905 - val_accuracy: 0.1925 - val_loss: 5.9229 - learning_rate: 5.1334e-04
# Epoch 15/25
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 34s 1s/step - accuracy: 0.1237 - loss: 6.2599 - val_accuracy: 0.1960 - val_loss: 5.8639 - learning_rate: 4.8767e-04
# Epoch 16/25
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 33s 1s/step - accuracy: 0.1344 - loss: 6.1415 - val_accuracy: 0.1990 - val_loss: 5.8078 - learning_rate: 4.6329e-04
# Epoch 17/25
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 34s 1s/step - accuracy: 0.1327 - loss: 6.1187 - val_accuracy: 0.2150 - val_loss: 5.7506 - learning_rate: 4.4013e-04
# Epoch 18/25
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 34s 1s/step - accuracy: 0.1459 - loss: 6.0309 - val_accuracy: 0.2231 - val_loss: 5.6937 - learning_rate: 4.1812e-04
# Epoch 19/25
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 35s 1s/step - accuracy: 0.1575 - loss: 5.9451 - val_accuracy: 0.2272 - val_loss: 5.6382 - learning_rate: 3.9721e-04
# Epoch 20/25
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 33s 1s/step - accuracy: 0.1648 - loss: 5.8669 - val_accuracy: 0.2402 - val_loss: 5.5837 - learning_rate: 3.7735e-04
# Epoch 21/25
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 33s 1s/step - accuracy: 0.1775 - loss: 5.8088 - val_accuracy: 0.2492 - val_loss: 5.5269 - learning_rate: 3.5849e-04
# Epoch 22/25
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 36s 1s/step - accuracy: 0.1847 - loss: 5.7470 - val_accuracy: 0.2715 - val_loss: 5.4704 - learning_rate: 3.4056e-04
# Epoch 23/25
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 35s 1s/step - accuracy: 0.2079 - loss: 5.6635 - val_accuracy: 0.2752 - val_loss: 5.4167 - learning_rate: 3.2353e-04
# Epoch 24/25
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 35s 1s/step - accuracy: 0.2081 - loss: 5.6262 - val_accuracy: 0.2953 - val_loss: 5.3631 - learning_rate: 3.0736e-04
# Epoch 25/25
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 35s 1s/step - accuracy: 0.2278 - loss: 5.5525 - val_accuracy: 0.3060 - val_loss: 5.3127 - learning_rate: 2.9199e-04

# %%
# %% Plot training and validation loss
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.title('Model Training Result')
# plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(loc='upper right')
plt.grid()
plt.show()

plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Validation Result')
# plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(loc='upper right')
plt.grid()
plt.show()

# %%
# %% Save the model
model.save(f'export/SEQ_lstm_loss_{history.history['loss'][-1]}.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
# Take sample from validation dataset to try summary
df_predict = df_filtered_full[1000:1100]

# %%
df_predict
# Out:
#                                                    text  \
# 1000  algiers aljazair antara news pada rabu waktu s...
# 1001  jakarta kepala divisi humas polri inspektur je...
# 1002  smartphone telah menyatu dengan kehidupan menu...
# 1003  jakarta chicco jerikho tidak merayakan lebaran...
# 1004  jakarta presiden meksiko enrique pena nieto me...
# ...                                                 ...
# 1095  jakarta manchester city menang telak atas leic...
# 1096  jakarta kepolisian kota strasburg negara bagia...
# 1097  tangerang polda metro jaya melalukan identifik...
# 1098  jakarta wakil gubernur dki jakarta sandiaga un...
# 1099  jakarta pabrikan otomotif asal china wuling ak...
#
#                                                 summary
# 1000  organisasi negara pengekspor minyak opec membu...
# 1001  kepala divisi humas polri inspektur jenderal s...
# 1002  bagi pengguna smartphone berbasis android goog...
# 1003  chicco jerikho tidak merayakan lebaran meski b...
# 1004  presiden meksiko enrique pena nieto menunda re...
# ...                                                 ...
# 1095  manchester city menang telak atas leicester ci...
# 1096  mulai bulan ini kepolisian strasburg negara ba...
# 1097  polda metro jaya melalukan identifikasi korban...
# 1098  wakil gubernur dki jakarta sandiaga uno memper...
# 1099  pabrikan otomotif asal china wuling akan seger...
#
# [100 rows x 2 columns]

# %%
df_predict.reset_index(inplace = True, drop = True)
df_predict.index = np.arange(len(df_predict))

# %%
df_predict
# Out:
#                                                  text  \
# 0   algiers aljazair antara news pada rabu waktu s...
# 1   jakarta kepala divisi humas polri inspektur je...
# 2   smartphone telah menyatu dengan kehidupan menu...
# 3   jakarta chicco jerikho tidak merayakan lebaran...
# 4   jakarta presiden meksiko enrique pena nieto me...
# ..                                                ...
# 95  jakarta manchester city menang telak atas leic...
# 96  jakarta kepolisian kota strasburg negara bagia...
# 97  tangerang polda metro jaya melalukan identifik...
# 98  jakarta wakil gubernur dki jakarta sandiaga un...
# 99  jakarta pabrikan otomotif asal china wuling ak...
#
#                                               summary
# 0   organisasi negara pengekspor minyak opec membu...
# 1   kepala divisi humas polri inspektur jenderal s...
# 2   bagi pengguna smartphone berbasis android goog...
# 3   chicco jerikho tidak merayakan lebaran meski b...
# 4   presiden meksiko enrique pena nieto menunda re...
# ..                                                ...
# 95  manchester city menang telak atas leicester ci...
# 96  mulai bulan ini kepolisian strasburg negara ba...
# 97  polda metro jaya melalukan identifikasi korban...
# 98  wakil gubernur dki jakarta sandiaga uno memper...
# 99  pabrikan otomotif asal china wuling akan seger...
#
# [100 rows x 2 columns]

# %%
# Prediction and decoding functions
def decode_sequence(sequence):
    return ' '.join([tokenizer.index_word.get(i, '') for i in sequence if i != 0])

def generate_summary(article):
    article_sequence = tokenizer.texts_to_sequences([article])
    article_padded = pad_sequences(article_sequence, maxlen=max_text_len, padding='post')
    predicted = model.predict(article_padded)
    predicted_sequence = np.argmax(predicted, axis=-1)
    return decode_sequence(predicted_sequence[0])

# %%
# Try to summary from existing data
predicted_summaries = []
reference_summaries = []

for i in range(len(df_predict)):
    predicted_summary = generate_summary(df_predict['text'][i])
    
    
    predicted_summaries.append(predicted_summary)
    reference_summaries.append(df_predict['summary'][i])
    # print(predicted_summary)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 310ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step

# %%
for i in range(len(predicted_summaries[:5])):
    print("Referenced: ", reference_summaries[i])
    print("Predicted: ", predicted_summaries[i])
    print("\n")
# Out:
# Referenced:  organisasi negara pengekspor minyak opec membuat keputusan bersejarah dengan memangkas target produksi minyak bagi negara negara anggotanya ke tingkat moderat selama beberapa tahun terakhir opec tercatat tidak berhasil merumuskan konsensus bagi anggotanya akibat silang pendapat antara arab saudi dan rivalnya iran keputusanini pun ditanggapi positif oleh pasar dengan kenaikan harga minyak sebesar 5 persen di atas us 48 per barel
# Predicted:  manajer dan pada depan tidak timur dan asal dan dan dan pada dirinya menurut yang dilakukan membuat timur asal dirinya di dirinya menurut ini dan dan dirinya di membuat dirinya dan serta menurut menurut yang skor dan tak dilakukan yakni dan di ini di dua dirinya tahun dan yakni dirinya untuk dirinya yakni lalu di dirinya yang dirinya sebelumnya dirinya dan dengan dan pada depan sebelumnya lebih dan dilakukan di berada di dan akan dirinya timur dan the dan hukum di dirinya menurut hari dan of menurut saat ini dirinya di di dirinya menurut hari dirinya satu depan untuk dirinya menurut harus dan dan menurut menurut dua lalu dan ini akan dan menurut menurut dan yang dirinya tahun lalu akan dan dilakukan menurut melakukan akan dirinya menurut akan dirinya pada depan di dan menurut di di skor dan akan akan sang melakukan melakukan dirinya dan di menurut untuk dan dan dan menurut menurut dan lain di lebih dirinya dan menurut menurut membuat asal yakni di akan dirinya pada depan dan yang sebelumnya yakni dirinya di dirinya tahun dirinya dan akan berada dirinya lainnya dirinya dan ini dilakukan sebelumnya dan dan dalam masa tahun ini satu dirinya masih dirinya ini depan menurut menurut dan dan dan menurut asal dirinya menurut dan menurut pada dirinya menurut di dan menurut
#
#
# Referenced:  kepala divisi humas polri inspektur jenderal setyo wasisto menyebutkan bom panci yang meledak di kampung melayu berisi paku dan gotri di bom panci ditemukan paku dan gotri jadi panci di dalamnya ada paku dan gotri kemudian di taruh di dalam ransel kata setyo setyo mengatakan hasil olah tkp menunjukan dua pelaku yang tewas membawa panci di dalam ranselnya
# Predicted:  jakarta di dirinya menurut menurut menurut hukum dan dan berada menurut dan yang dirinya di masa dan anak timur yakni the dirinya menurut dan di menurut dan depan dirinya dan depan dirinya di dirinya ada dirinya dan depan di di dalam lalu dirinya di depan menurut lainnya menurut dunia menurut the dan mengatakan asal menurut berada menurut dan menurut dan tahun asal yang dan berada dan di dalam ada ada dirinya yang stadion ke masa lalu dan menurut dari dirinya dan yang depan dalam ada satu dirinya asal menurut dan di pada berada menurut berada yakni itu dirinya di ada satu dan dan di depan di dirinya asal ada tidak dan dan ada depan menurut dan dan dan di tersebut membuat dirinya dirinya dari menurut dan di yang dirinya kali di dan dua orang asal dan sebelumnya di harus di masih sebelumnya depan di berada dirinya menurut dan menurut menurut sudah depan yakni kali the dirinya menurut di dirinya menurut dan jakarta timur ada satu the dirinya yang dilakukan orang di berada dirinya lainnya dirinya di di menurut menurut yang akan dan dan dan dan berada menurut dirinya di depan membuat dirinya dalam dan seperti dirinya yang masih dalam dirinya menurut dari dirinya dan ada dirinya dan masa sudah dirinya ke di masa menurut dirinya menurut
#
#
# Referenced:  bagi pengguna smartphone berbasis android google telah memfasilitasi kebutuhan itu dengan fitur find my device make sure anda telah mengaktifkan hanya butuh 5 menit kok untuk mengaturnya agar melacak perangkat android yang hilang dengan find my phone pastikan find my device dan fitur lokasi aktif jika anda menyembunyikan perangkat di google play pastikan visibilitas aktif
# Predicted:  sudah dirinya dengan dirinya dan belum dirinya dan di membuat dan lebih dirinya dan dan dan menurut membuat dirinya dilakukan dirinya menurut dirinya ke dirinya asal itu skor dirinya dan menurut menurut yang dirinya menurut tidak dan di menurut menurut dan dan dari itu depan menurut 5 menurut menurut sebelumnya sebelumnya masih bisa skor untuk dirinya dan skor dari dirinya menurut di dirinya menurut warga dan dan tidak dan warga menurut dan dirinya seperti satu dirinya itu dengan depan dirinya dan menurut sebelumnya satu hanya dirinya the yakni menurut untuk di dan dan dirinya yang dirinya dengan dirinya dan menurut kota dirinya of menurut menurut dan menurut tak dan dan menurut sang dari dirinya menurut menurut dengan dirinya di dan tahun dan membuat masih dirinya menurut dirinya dan untuk depan dirinya dan menurut sebelumnya satu dirinya dan di timur dirinya dan di depan dan dan tidak akan dirinya di dirinya dan menurut untuk dirinya dan ada kota dan di yang bisa sebelumnya dirinya hukum dan dan untuk dan dengan depan menurut asal the yakni depan dirinya untuk dirinya dan dirinya menurut dan dilakukan dirinya hukum dan untuk skor menurut di dan dirinya dari dirinya menurut dirinya dirinya menurut dan dan menurut menurut bisa menjadi dirinya dan menurut dan dan menurut menurut dan dan dirinya dan menurut the dirinya dan dan depan dirinya menurut menjadi dan dan asal
#
#
# Referenced:  chicco jerikho tidak merayakan lebaran meski begitu chicco tetap ikut merasakan gegap gempitanya dan mengikuti tradisinya apalagi soal makanan chicco mengatakan makanan favoritnya adalah ketupat ia rela berburu ketupat ke mana mana saya sudah tanya sahabat sahabat di mana ada ketupat enak saya akan ke sana saya sudah observasi untuk itu yang enak biasanya yang mana kata chicco bercerita
# Predicted:  jakarta tidak skor menurut lalu yakni di depan sebelumnya depan dan dan depan dirinya menurut di 12 dirinya dan dari dirinya menurut menurut baru tidak lalu di nama ia dirinya dan ke skor menurut hukum sudah dan dan dan di skor ada dirinya akan ke dirinya hukum sudah untuk itu yang dirinya dirinya yang skor lalu dirinya menurut ada satu dirinya yang dirinya menjadi dirinya di menurut namun timur ini sudah dirinya dan di lalu dirinya menurut tidak dan dan menurut ke dua dirinya hukum sudah dan hukum lebih dirinya dan dan dari tahun dirinya dan dan menurut seperti tahun dan menurut dan pada timur yakni sebelumnya lalu tidak menurut ia berada dilakukan dirinya di dan di tak bisa ke tahun dirinya menurut sudah ada tidak dirinya dan yang depan namun dengan dirinya seperti the dirinya itu dirinya ia akan dirinya nasional yang depan dan nasional berada dirinya sudah ada yang dan hukum ada yang dan dan menurut menurut dan itu dirinya dirinya dan dan menurut menurut di depan dirinya dan menurut dengan dirinya dan itu dirinya yang berada dan dan di skor itu dilakukan yang dirinya depan dan akan dirinya hukum depan dirinya menurut dari dan dilakukan dirinya orang
#
#
# Referenced:  presiden meksiko enrique pena nieto menunda rencana kunjungannya ke amerika untuk bertemu dengan donald trump pejabat senior as mengungkapkan bahwa penundaan ini terjadi setelah adanya panggilan telepon trump ke nieto terkait tembok perbatasan kedua pemimpin sepakat bahwa sekarang bukanlah saat yang tepat untuk berkunjung tapi mereka akan tetap terus berkomunikasi dan bekerjasama kata pejabat tersebut
# Predicted:  jakarta dirinya menurut menurut menurut menurut lainnya menurut ke sebelumnya untuk depan dengan dan dan menurut menurut hukum dan sudah ini dilakukan di berada dirinya menurut dan ke dirinya dunia dan menurut di menurut menurut sudah dirinya dan dari yang dirinya untuk dan hukum akan akan sebelumnya kali dan dan dirinya hal menurut tersebut dari dirinya menurut menurut sudah dan sudah depan menurut hukum dan dan dirinya akan depan pada tidak lebih ke depan lain menurut menurut the dirinya menurut dan sudah tahun dirinya tersebut dirinya hal harus menurut yakni pada depan lalu namun dirinya tersebut dirinya dunia dirinya di dan tak dirinya untuk di depan dirinya lain dan tak akan berada dan menurut hukum dirinya the menurut dirinya mengatakan tak dan menurut asal dan tersebut sebelumnya sebelumnya menurut hukum menurut dan dan ke dua yang dan dan dan akan tak ada masa dirinya untuk dirinya dirinya dari dirinya dan dan untuk dirinya berada dan tersebut dirinya menurut

# %%
from rouge_score import rouge_scorer
import numpy as np

# Function to evaluate using ROUGE and store precision, recall, and F-measure
def evaluate_rouge(predicted_summaries, reference_summaries):
    # Initialize ROUGE scorer
    scorer = rouge_scorer.RougeScorer(['rouge1', 'rouge2', 'rougeL'], use_stemmer=True)
    
    # Initialize lists to accumulate precision, recall, and F-measure for each metric
    rouge1_precision, rouge1_recall, rouge1_fmeasure = [], [], []
    rouge2_precision, rouge2_recall, rouge2_fmeasure = [], [], []
    rougeL_precision, rougeL_recall, rougeL_fmeasure = [], [], []
    
    # Calculate ROUGE scores for each pair of reference and generated summaries
    for ref_summary, pred_summary in zip(reference_summaries, predicted_summaries):
        scores = scorer.score(ref_summary, pred_summary)
        
        # Store precision, recall, and F-measure for each ROUGE metric
        rouge1_precision.append(scores['rouge1'].precision)
        rouge1_recall.append(scores['rouge1'].recall)
        rouge1_fmeasure.append(scores['rouge1'].fmeasure)
        
        rouge2_precision.append(scores['rouge2'].precision)
        rouge2_recall.append(scores['rouge2'].recall)
        rouge2_fmeasure.append(scores['rouge2'].fmeasure)
        
        rougeL_precision.append(scores['rougeL'].precision)
        rougeL_recall.append(scores['rougeL'].recall)
        rougeL_fmeasure.append(scores['rougeL'].fmeasure)
    
    # Calculate the average precision, recall, and F-measure for each metric
    results = {
        "ROUGE-1": {
            "precision": np.mean(rouge1_precision),
            "recall": np.mean(rouge1_recall),
            "fmeasure": np.mean(rouge1_fmeasure)
        },
        "ROUGE-2": {
            "precision": np.mean(rouge2_precision),
            "recall": np.mean(rouge2_recall),
            "fmeasure": np.mean(rouge2_fmeasure)
        },
        "ROUGE-L": {
            "precision": np.mean(rougeL_precision),
            "recall": np.mean(rougeL_recall),
            "fmeasure": np.mean(rougeL_fmeasure)
        }
    }
    
    return results

# %%
# Evaluate ROUGE scores
rouge_scores = evaluate_rouge(predicted_summaries, reference_summaries)
print("ROUGE Scores:")
for key, value in rouge_scores.items():
    print(f"{key}: {value}")
# Out:
# ROUGE Scores:
# ROUGE-1: {'precision': 0.07212184605464564, 'recall': 0.21359054591879328, 'fmeasure': 0.10644750543322999}
# ROUGE-2: {'precision': 0.009394374657353188, 'recall': 0.028442371997134838, 'fmeasure': 0.01395772464870353}
# ROUGE-L: {'precision': 0.06592010118127999, 'recall': 0.19584325350466514, 'fmeasure': 0.09738073366571932}
